# %%
import time
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests
from IPython.core.display import display, HTML
from bs4 import BeautifulSoup
from tqdm import tqdm
from glob import glob

display(HTML("<style>.container { width:100% !important; }</style>"))

plt.style.use('fivethirtyeight')

import warnings
warnings.filterwarnings('ignore')
# Out:
# /var/folders/0l/bxmy5l011594gflgwzxxndhr0000gn/T/ipykernel_67546/442065751.py:7: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>

# %%
def convert_season_to_int(season):
    season = season.split('-')[0]
    return int(season) + 1

def convert_int_to_season(year):
    previuos_year = year - 1
    year = str(year)
    previous_year = str(previuos_year)
    year = year[-2:]
    return f'{previous_year}-{year}'

# %%
def getSoupFromURL(url):

    try:
        r = requests.get(url)
    except:
        return None

    return BeautifulSoup(r.text, "html.parser")

def relative_table(table, avg_table, skip_names):
    for column_name in table.columns:
        if column_name in skip_names:
            continue
    
        table[f'{column_name}'] = (table[f'{column_name}'] / avg_table[f'{column_name}']) - 1
        
    return table

def get_bbref_teams_dataframe(first_year,
                              last_year,
                              find_champion=True,
                              save=True,
                              relative=True,
                              time_to_sleep=2):

    all_teams = pd.DataFrame()

    for i, year in tqdm(enumerate(range(first_year, last_year + 1)), total=last_year + 1 - first_year):

        url = f'https://www.basketball-reference.com/leagues/NBA_{year}.html'

        advanced_table_id = "advanced-team"
        per_game_table_id = 'per_game-team'

        soup = getSoupFromURL(url)
        time.sleep(time_to_sleep)

        advanced_table = soup.find(lambda tag: tag.name=='table' and tag.has_attr('id') and tag['id']==advanced_table_id)
        per_game_table = soup.find(lambda tag: tag.name=='table' and tag.has_attr('id') and tag['id']==per_game_table_id)
        
        if find_champion:
            champion = soup.find(lambda tag: tag.name=='div' and tag.has_attr('id') and tag['id']=='info')
            champion_name = " ".join(champion.find_all('div')[2].find('p').text.split(" ")[2:])

        advanced_stats = pd.read_html(str(advanced_table), header=1)[0]
        advanced_stats = advanced_stats.drop(['Unnamed: 17', 'Unnamed: 22', 'Unnamed: 27', 'Arena', 'Attend.'], axis=1)
        advanced_league_avg = advanced_stats.iloc[-1]
        advanced_stats = advanced_stats[:-1]

        per_game_stats = pd.read_html(str(per_game_table), header=0)[0]
        per_game_league_avg = per_game_stats.iloc[-1]
        per_game_stats = per_game_stats[:-1]
        
        if relative:
            per_game_stats = relative_table(per_game_stats, per_game_league_avg, skip_names=['Team', 'Rk'])
            advanced_stats = relative_table(advanced_stats, advanced_league_avg, skip_names=['Team', 'Rk', 'W', 'L', 'MOV', 'SOS', 'SRS', 'NRtg'])

        combined_team_stats = pd.merge(per_game_stats, advanced_stats, on=['Team'])
        combined_team_stats['Team'] = combined_team_stats['Team'].str.replace('*', '')

        combined_team_stats['Season'] = convert_int_to_season(year)
        combined_team_stats['Win%'] = combined_team_stats['W'] / (combined_team_stats['W'] + combined_team_stats['L'])
        
        combined_team_stats = combined_team_stats.fillna(0)
        combined_team_stats = combined_team_stats.drop(['Rk_x', 'Rk_y', 'G', 'MP'], axis=1)
        
        if find_champion:
            combined_team_stats['Champion'] = 0
            combined_team_stats.loc[combined_team_stats['Team'] == champion_name, 'Champion'] = 1
            
            if combined_team_stats.Champion.sum() != 1:
                print(f'[ERROR] - {year}')
                break
                
        all_teams = pd.concat([all_teams, combined_team_stats])
        
        time.sleep(5)

    if save:
        all_teams.to_csv('historical_relative_data.csv')
    
    return all_teams

# %%
first_year = 1980
last_year = 2024

file_name = 'historical_relative_data.csv'
if os.path.exists(file_name):
    print('File exists - loading from disk')
    teams = pd.read_csv(file_name)
else:
    teams = get_bbref_teams_dataframe(first_year, last_year, save=True)
# Out:
# File exists - loading from disk

# %%
teams
# Out:
#       Unnamed: 0                    Team        FG       FGA       FG%  \
# 0              0       San Antonio Spurs  0.077982  0.041943  0.035343
# 1              1      Los Angeles Lakers  0.089450 -0.007726  0.099792
# 2              2     Cleveland Cavaliers  0.066514  0.082781 -0.014553
# 3              3         New York Knicks  0.064220  0.033113  0.031185
# 4              4          Boston Celtics  0.011468 -0.005519  0.018711
# ...          ...                     ...       ...       ...       ...
# 1249          25              Miami Heat -0.056872 -0.037120 -0.018987
# 1250          26         Detroit Pistons -0.030806 -0.007874 -0.023207
# 1251          27       Charlotte Hornets -0.052133 -0.021372 -0.029536
# 1252          28  Portland Trail Blazers -0.066351  0.008999 -0.073840
# 1253          29       Memphis Grizzlies -0.090047 -0.007874 -0.082278
#
#             3P       3PA       3P%        2P       2PA  ...      ORB%  \
# 0    -0.250000 -0.107143 -0.100000  0.081585  0.045506  ... -0.050746
# 1    -0.750000 -0.571429 -0.285714  0.102564  0.007964  ... -0.026866
# 2    -0.500000 -0.178571 -0.310714  0.072261  0.089875  ... -0.011940
# 3    -0.375000 -0.178571 -0.214286  0.069930  0.037543  ...  0.005970
# 4     1.500000  0.821429  0.371429 -0.018648 -0.034130  ...  0.038806
# ...        ...       ...       ...       ...       ...  ...       ...
# 1249 -0.023438 -0.039886  0.010929 -0.064846 -0.035316  ... -0.099174
# 1250 -0.140625 -0.096866 -0.049180  0.017065  0.050186  ... -0.012397
# 1251 -0.054688 -0.031339 -0.030055 -0.044369 -0.014870  ... -0.128099
# 1252 -0.101562 -0.054131 -0.057377 -0.047782  0.050186  ...  0.136364
# 1253  0.023438  0.076923 -0.054645 -0.136519 -0.063197  ... -0.016529
#
#         FT/FGA    eFG%.1    TOV%.1      DRB%  FT/FGA.1  Attend./G   Season  \
# 0     0.114894  0.041152 -0.070968  0.004511 -0.080851  -0.345574  1979-80
# 1    -0.063830 -0.022634 -0.096774  0.006015 -0.229787  -0.720000  1979-80
# 2    -0.097872  0.039095  0.051613 -0.009023 -0.080851  -0.220328  1979-80
# 3    -0.059574  0.024691  0.058065 -0.037594  0.119149  -0.060984  1979-80
# 4     0.097872 -0.022634  0.064516  0.019549 -0.004255   8.501639  1979-80
# ...        ...       ...       ...       ...       ...        ...      ...
# 1249  0.093750 -0.007313  0.049587  0.030343 -0.093750   0.077469  2023-24
# 1250  0.005208  0.020110 -0.082645  0.019789  0.151042  -0.009329  2023-24
# 1251 -0.130208  0.045704  0.016529 -0.017150 -0.020833  -0.102619  2023-24
# 1252 -0.057292  0.020110  0.057851 -0.023747  0.125000  -0.000164  2023-24
# 1253 -0.052083  0.007313  0.115702 -0.013193  0.015625  -0.092690  2023-24
#
#           Win%  Champion
# 0     0.500000         0
# 1     0.731707         1
# 2     0.451220         0
# 3     0.475610         0
# 4     0.743902         0
# ...        ...       ...
# 1249  0.560976         0
# 1250  0.170732         0
# 1251  0.256098         0
# 1252  0.256098         0
# 1253  0.329268         0
#
# [1254 rows x 50 columns]

# %%
import seaborn as sns
# Assuming teams DataFrame is already defined
corr = teams.select_dtypes(include=np.number).corr()

# Create a heatmap with the correlation matrix
plt.figure(figsize=(40, 38))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
# FTA         0.178281 -0.034754
# FT%         0.199136 -0.015133
# ORB        -0.142218 -0.033922
# DRB         0.514131  0.181610
# TRB         0.315235  0.122251
# AST         0.420993  0.176054
# STL         0.143066  0.036885
# BLK         0.227480  0.121976
# TOV        -0.353651 -0.060280
# PF         -0.275075 -0.144147
# PTS         0.512344  0.146170
# Age         0.529679  0.198634
# W           0.972256  0.291782
# L          -0.970707 -0.291244
# PW          0.969621  0.284477
# PL         -0.969141 -0.285735
# MOV         0.968436  0.291415
# SOS        -0.431068 -0.131863
# SRS         0.965565  0.290369
# ORtg        0.771994  0.221390
# DRtg       -0.713725 -0.226778
# NRtg        0.968555  0.291398
# Pace       -0.113523 -0.023575
# FTr         0.204767 -0.024916
# 3PAr        0.166713  0.031059
# TS%         0.705128  0.216283
# eFG%        0.694033  0.249140
# TOV%       -0.304266 -0.044016
# ORB%        0.074851  0.042705
# FT/FGA      0.259850 -0.031447
# eFG%.1     -0.667567 -0.220373
# TOV%.1      0.055021 -0.012240
# DRB%        0.368717  0.105583
# FT/FGA.1   -0.289356 -0.144986
# Attend./G   0.265770  0.104362
# Win%        1.000000  0.299222
# Champion    0.299222  1.000000
#
# [48 rows x 48 columns]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
import xgboost as xgb
from sklearn.svm import SVC
from sklearn.pipeline import make_pipeline
from sklearn.feature_selection import SelectKBest, f_classif, mutual_info_classif
from catboost import CatBoostClassifier, Pool

def drop_highly_correlated_features(df, threshold=0.95):
    corr_matrix = df.corr().abs()

    # Select the upper triangle of the correlation matrix
    upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

    # Find features with correlation above threshold
    to_drop = [column for column in upper.columns if any(upper[column] > threshold)]

    # print(f"Features to drop (correlation > {threshold}): {to_drop}")
    return df.drop(columns=to_drop), to_drop

def create_and_train_svm(x_train, y_train, x_test):
    clf = make_pipeline(SVC(gamma='auto', probability=True))
    clf.fit(x_train, y_train)
    
    probs = clf.predict_proba(x_test)
    return 100 * probs[:,1]

def create_and_train_xgb(x_train, y_train, x_test):

    dtrain = xgb.DMatrix(x_train, label=y_train)
    param = {'max_depth': 2, 'eta': 1, 'objective': 'binary:logistic'}
    param['nthread'] = 4
    param['eval_metric'] = 'auc'
    
    evallist = [(dtrain, 'train')]
    
    num_round = 100
    bst = xgb.train(param, dtrain, num_round, evallist, verbose_eval=False)
    dtest = xgb.DMatrix(x_test)
    ypred = bst.predict(dtest)
    return 100 * ypred

def create_and_train_lr(x_train, y_train, x_test):
    lr = LogisticRegression(
        penalty='l2',
        solver='newton-cholesky',
        C=0.1
    )
    lr.fit(x_train, y_train)
    probs = lr.predict_proba(x_test)[:,1]
    
    lr_probs = 100 * probs
    return lr_probs

def create_and_train_lda(x_train, y_train, x_test):
    clf = LinearDiscriminantAnalysis()
    clf.fit(x_train, y_train)
    
    lda_probs = clf.predict_proba(x_test)
    return 100 * lda_probs[:,1]

def create_and_train_cat_boost(x_train, y_train, x_test):
    model = CatBoostClassifier(iterations=20,
                               depth=2,
                               learning_rate=0.1,
                               loss_function='Logloss',
                               verbose=False)
    model.fit(x_train, y_train)
    preds_proba = model.predict_proba(x_test)
    return 100 * preds_proba[:,1]
    

def select_features(x_train, y_train, x_test, k=10):
    selector = SelectKBest(score_func=f_classif, k=k)
    for df in [x_train, x_test]:
        if "Unnamed: 0" in df.columns:
            df.drop(columns=["Unnamed: 0"], inplace=True)
    x_train_selected = selector.fit_transform(x_train, y_train.values.ravel())
    x_test_selected = selector.transform(x_test)
    return x_train_selected, x_test_selected, selector

def create_and_train_big_model(x_train, y_train, x_test, k=10, threshold=0.8):
    x_train, to_drop = drop_highly_correlated_features(x_train, threshold=threshold)
    x_test = x_test.drop(columns=to_drop)
    x_train_selected, x_test_selected, selector = select_features(x_train, y_train, x_test, k)

    model_probs = []

    # model_probs.append(create_and_train_svm(x_train_selected, y_train, x_test_selected))
    model_probs.append(create_and_train_xgb(x_train_selected, y_train, x_test_selected))
    # model_probs.append(create_and_train_lr(x_train_selected, y_train, x_test_selected))
    # model_probs.append(create_and_train_lda(x_train_selected, y_train, x_test_selected))
    model_probs.append(create_and_train_cat_boost(x_train, y_train, x_test))

    # Step 3: Average probabilities
    # If no models are selected, we return an empty array or handle the case where no models are used
    if model_probs:
        avg_probs = sum(model_probs) / len(model_probs)

        total = avg_probs.sum()
        if total > 0:
            normalized_probs = (avg_probs / total) * 100
        else:
            normalized_probs = avg_probs  # fallback if somehow sum is 0

        return normalized_probs
    else:
        raise ValueError("No models selected. Please uncomment at least one model.")

# %%
teams['Season'] = teams['Season'].astype(str)

# Get unique seasons
seasons = teams['Season'].unique()
print_results = True
save = False

# K-folds by leave-one-season-out
results = []  # to store all season-wise records
correct_predictions = 0  # to accumulate the number of correct predictions

for i, season in enumerate(seasons):
    test_df = teams[teams['Season'] == season].reset_index(drop=True)
    train_df = teams[teams['Season'] != season].reset_index(drop=True)

    x_train = train_df.drop(columns=["Champion", "Season", "Team"])
    y_train = train_df[["Champion"]]

    x_test = test_df.drop(columns=["Champion", "Season", "Team"])
    y_test = test_df[["Champion"]]

    test_df["avg_prob"] = create_and_train_big_model(x_train, y_train, x_test, k=20, threshold=0.8)

    # Predicted champion
    predicted_row = test_df.loc[test_df["avg_prob"].idxmax()]
    predicted_team = predicted_row["Team"]
    predicted_prob = predicted_row["avg_prob"]

    # Actual champion
    true_champion_row = test_df[test_df["Champion"] == 1]
    if not true_champion_row.empty:
        true_team = true_champion_row.iloc[0]["Team"]
        true_prob = true_champion_row.iloc[0]["avg_prob"]
    else:
        true_team = None
        true_prob = None

    correct = predicted_team == true_team
    correct_predictions += correct  # Increment correct prediction counter

    # Store result
    results.append({
        "Season": season,
        "Predicted Champion": predicted_team,
        "Predicted Prob": round(predicted_prob, 2),
        "Actual Champion": true_team,
        "Actual Prob": round(true_prob, 2) if true_prob is not None else None,
        "Correct": correct
    })

    if print_results:
        # Optional console output
        print(f"\n📅 Season: {season}")
        print(f"🏆 Predicted Champion: {predicted_team} (Prob: {predicted_prob:.2f}%)")
        print(f"👑 Actual Champion:    {true_team} (Prob: {true_prob:.2f}%)")
        print("✅ Correct prediction!" if correct else "❌ Wrong prediction!")

# Calculate accuracy after all seasons have been processed
total_seasons = len(seasons)
accuracy = (correct_predictions / total_seasons) * 100

print(f"\n🎯 Overall Prediction Accuracy: {accuracy:.2f}% ({correct_predictions} out of {total_seasons} seasons)")

if save:
    # Optionally save the results to CSV
    results_df = pd.DataFrame(results)
    results_df.to_csv("champion_predictions.csv", index=False)
    print(f"\n📁 Results saved to 'champion_predictions.csv'")
# Out:
# 📅 Season: 1979-80
# 🏆 Predicted Champion: Boston Celtics (Prob: 21.04%)
# 👑 Actual Champion:    Los Angeles Lakers (Prob: 16.70%)
# ❌ Wrong prediction!
#
# 📅 Season: 1980-81
# 🏆 Predicted Champion: Philadelphia 76ers (Prob: 37.79%)
# 👑 Actual Champion:    Boston Celtics (Prob: 14.02%)
# ❌ Wrong prediction!
#
# 📅 Season: 1981-82
# 🏆 Predicted Champion: Boston Celtics (Prob: 47.98%)
# 👑 Actual Champion:    Los Angeles Lakers (Prob: 15.54%)
# ❌ Wrong prediction!
#
# 📅 Season: 1982-83
# 🏆 Predicted Champion: Los Angeles Lakers (Prob: 55.98%)
# 👑 Actual Champion:    Philadelphia 76ers (Prob: 17.93%)
# ❌ Wrong prediction!
#
# 📅 Season: 1983-84
# 🏆 Predicted Champion: Boston Celtics (Prob: 45.04%)
# 👑 Actual Champion:    Boston Celtics (Prob: 45.04%)
# ✅ Correct prediction!
#
# 📅 Season: 1984-85
# 🏆 Predicted Champion: Los Angeles Lakers (Prob: 56.35%)
# 👑 Actual Champion:    Los Angeles Lakers (Prob: 56.35%)
# ✅ Correct prediction!
#
# 📅 Season: 1985-86
# 🏆 Predicted Champion: Boston Celtics (Prob: 51.03%)
# 👑 Actual Champion:    Boston Celtics (Prob: 51.03%)
# ✅ Correct prediction!
#
# 📅 Season: 1986-87
# 🏆 Predicted Champion: Los Angeles Lakers (Prob: 51.27%)
# 👑 Actual Champion:    Los Angeles Lakers (Prob: 51.27%)
# ✅ Correct prediction!
#
# 📅 Season: 1987-88
# 🏆 Predicted Champion: Los Angeles Lakers (Prob: 32.10%)
# 👑 Actual Champion:    Los Angeles Lakers (Prob: 32.10%)
# ✅ Correct prediction!
#
# 📅 Season: 1988-89
# 🏆 Predicted Champion: Detroit Pistons (Prob: 21.71%)
# 👑 Actual Champion:    Detroit Pistons (Prob: 21.71%)
# ✅ Correct prediction!
#
# 📅 Season: 1989-90
# 🏆 Predicted Champion: Los Angeles Lakers (Prob: 24.55%)
# 👑 Actual Champion:    Detroit Pistons (Prob: 13.11%)
# ❌ Wrong prediction!
#
# 📅 Season: 1990-91
# 🏆 Predicted Champion: Chicago Bulls (Prob: 31.25%)
# 👑 Actual Champion:    Chicago Bulls (Prob: 31.25%)
# ✅ Correct prediction!
#
# 📅 Season: 1991-92
# 🏆 Predicted Champion: Chicago Bulls (Prob: 66.79%)
# 👑 Actual Champion:    Chicago Bulls (Prob: 66.79%)
# ✅ Correct prediction!
#
# 📅 Season: 1992-93
# 🏆 Predicted Champion: Houston Rockets (Prob: 26.57%)
# 👑 Actual Champion:    Chicago Bulls (Prob: 7.89%)
# ❌ Wrong prediction!
#
# 📅 Season: 1993-94
# 🏆 Predicted Champion: New York Knicks (Prob: 29.85%)
# 👑 Actual Champion:    Houston Rockets (Prob: 6.67%)
# ❌ Wrong prediction!
#
# 📅 Season: 1994-95
# 🏆 Predicted Champion: San Antonio Spurs (Prob: 34.02%)
# 👑 Actual Champion:    Houston Rockets (Prob: 1.29%)
# ❌ Wrong prediction!
#
# 📅 Season: 1995-96
# 🏆 Predicted Champion: Chicago Bulls (Prob: 56.58%)
# 👑 Actual Champion:    Chicago Bulls (Prob: 56.58%)
# ✅ Correct prediction!
#
# 📅 Season: 1996-97
# 🏆 Predicted Champion: Chicago Bulls (Prob: 54.35%)
# 👑 Actual Champion:    Chicago Bulls (Prob: 54.35%)
# ✅ Correct prediction!
#
# 📅 Season: 1997-98
# 🏆 Predicted Champion: Chicago Bulls (Prob: 39.65%)
# 👑 Actual Champion:    Chicago Bulls (Prob: 39.65%)
# ✅ Correct prediction!
#
# 📅 Season: 1998-99
# 🏆 Predicted Champion: San Antonio Spurs (Prob: 48.81%)
# 👑 Actual Champion:    San Antonio Spurs (Prob: 48.81%)
# ✅ Correct prediction!
#
# 📅 Season: 1999-00
# 🏆 Predicted Champion: Los Angeles Lakers (Prob: 52.46%)
# 👑 Actual Champion:    Los Angeles Lakers (Prob: 52.46%)
# ✅ Correct prediction!
#
# 📅 Season: 2000-01
# 🏆 Predicted Champion: San Antonio Spurs (Prob: 34.43%)
# 👑 Actual Champion:    Los Angeles Lakers (Prob: 3.92%)
# ❌ Wrong prediction!
#
# 📅 Season: 2001-02
# 🏆 Predicted Champion: San Antonio Spurs (Prob: 49.15%)
# 👑 Actual Champion:    Los Angeles Lakers (Prob: 8.64%)
# ❌ Wrong prediction!
#
# 📅 Season: 2002-03
# 🏆 Predicted Champion: Portland Trail Blazers (Prob: 23.36%)
# 👑 Actual Champion:    San Antonio Spurs (Prob: 15.20%)
# ❌ Wrong prediction!
#
# 📅 Season: 2003-04
# 🏆 Predicted Champion: Minnesota Timberwolves (Prob: 23.63%)
# 👑 Actual Champion:    Detroit Pistons (Prob: 2.53%)
# ❌ Wrong prediction!
#
# 📅 Season: 2004-05
# 🏆 Predicted Champion: San Antonio Spurs (Prob: 47.63%)
# 👑 Actual Champion:    San Antonio Spurs (Prob: 47.63%)
# ✅ Correct prediction!
#
# 📅 Season: 2005-06
# 🏆 Predicted Champion: San Antonio Spurs (Prob: 43.99%)
# 👑 Actual Champion:    Miami Heat (Prob: 1.90%)
# ❌ Wrong prediction!
#
# 📅 Season: 2006-07
# 🏆 Predicted Champion: Dallas Mavericks (Prob: 38.84%)
# 👑 Actual Champion:    San Antonio Spurs (Prob: 14.05%)
# ❌ Wrong prediction!
#
# 📅 Season: 2007-08
# 🏆 Predicted Champion: Boston Celtics (Prob: 46.44%)
# 👑 Actual Champion:    Boston Celtics (Prob: 46.44%)
# ✅ Correct prediction!
#
# 📅 Season: 2008-09
# 🏆 Predicted Champion: Cleveland Cavaliers (Prob: 32.12%)
# 👑 Actual Champion:    Los Angeles Lakers (Prob: 28.99%)
# ❌ Wrong prediction!
#
# 📅 Season: 2009-10
# 🏆 Predicted Champion: Cleveland Cavaliers (Prob: 23.00%)
# 👑 Actual Champion:    Los Angeles Lakers (Prob: 7.29%)
# ❌ Wrong prediction!
#
# 📅 Season: 2010-11
# 🏆 Predicted Champion: San Antonio Spurs (Prob: 46.23%)
# 👑 Actual Champion:    Dallas Mavericks (Prob: 7.79%)
# ❌ Wrong prediction!
#
# 📅 Season: 2011-12
# 🏆 Predicted Champion: Dallas Mavericks (Prob: 25.43%)
# 👑 Actual Champion:    Miami Heat (Prob: 5.47%)
# ❌ Wrong prediction!
#
# 📅 Season: 2012-13
# 🏆 Predicted Champion: San Antonio Spurs (Prob: 39.91%)
# 👑 Actual Champion:    Miami Heat (Prob: 23.67%)
# ❌ Wrong prediction!
#
# 📅 Season: 2013-14
# 🏆 Predicted Champion: Chicago Bulls (Prob: 20.65%)
# 👑 Actual Champion:    San Antonio Spurs (Prob: 15.42%)
# ❌ Wrong prediction!
#
# 📅 Season: 2014-15
# 🏆 Predicted Champion: Golden State Warriors (Prob: 50.95%)
# 👑 Actual Champion:    Golden State Warriors (Prob: 50.95%)
# ✅ Correct prediction!
#
# 📅 Season: 2015-16
# 🏆 Predicted Champion: San Antonio Spurs (Prob: 41.54%)
# 👑 Actual Champion:    Cleveland Cavaliers (Prob: 7.38%)
# ❌ Wrong prediction!
#
# 📅 Season: 2016-17
# 🏆 Predicted Champion: Golden State Warriors (Prob: 65.94%)
# 👑 Actual Champion:    Golden State Warriors (Prob: 65.94%)
# ✅ Correct prediction!
#
# 📅 Season: 2017-18
# 🏆 Predicted Champion: Houston Rockets (Prob: 29.40%)
# 👑 Actual Champion:    Golden State Warriors (Prob: 10.86%)
# ❌ Wrong prediction!
#
# 📅 Season: 2018-19
# 🏆 Predicted Champion: Golden State Warriors (Prob: 55.90%)
# 👑 Actual Champion:    Toronto Raptors (Prob: 3.99%)
# ❌ Wrong prediction!
#
# 📅 Season: 2019-20
# 🏆 Predicted Champion: Los Angeles Lakers (Prob: 31.99%)
# 👑 Actual Champion:    Los Angeles Lakers (Prob: 31.99%)
# ✅ Correct prediction!
#
# 📅 Season: 2020-21
# 🏆 Predicted Champion: Milwaukee Bucks (Prob: 14.73%)
# 👑 Actual Champion:    Milwaukee Bucks (Prob: 14.73%)
# ✅ Correct prediction!
#
# 📅 Season: 2021-22
# 🏆 Predicted Champion: Phoenix Suns (Prob: 33.83%)
# 👑 Actual Champion:    Golden State Warriors (Prob: 3.82%)
# ❌ Wrong prediction!
#
# 📅 Season: 2022-23
# 🏆 Predicted Champion: Boston Celtics (Prob: 17.13%)
# 👑 Actual Champion:    Denver Nuggets (Prob: 3.63%)
# ❌ Wrong prediction!
#
# 📅 Season: 2023-24
# 🏆 Predicted Champion: Boston Celtics (Prob: 26.90%)
# 👑 Actual Champion:    Boston Celtics (Prob: 26.90%)
# ✅ Correct prediction!
#
# 🎯 Overall Prediction Accuracy: 44.44% (20 out of 45 seasons)

# %%
import itertools
import pandas as pd
import pickle

# Modify this function to accept k and threshold as arguments for grid search
def perform_grid_search(seasons, teams, k_values, threshold_values, print_results=False, save=False):
    # To store results of the grid search
    grid_search_results = []

    # Perform grid search for k and threshold
    for k, threshold in tqdm(itertools.product(k_values, threshold_values)):
        print(f"Running grid search for k={k}, threshold={threshold}")

        # Initialize variables to store the correct predictions
        correct_predictions = 0
        results = []

        for i, season in enumerate(seasons):
            test_df = teams[teams['Season'] == season].reset_index(drop=True)
            train_df = teams[teams['Season'] != season].reset_index(drop=True)

            x_train = train_df.drop(columns=["Champion", "Season", "Team"])
            y_train = train_df[["Champion"]]

            x_test = test_df.drop(columns=["Champion", "Season", "Team"])
            y_test = test_df[["Champion"]]

            # Call your model training function with grid search parameters
            test_df["avg_prob"] = create_and_train_big_model(x_train, y_train, x_test, k=k, threshold=threshold)

            # Predicted champion
            predicted_row = test_df.loc[test_df["avg_prob"].idxmax()]
            predicted_team = predicted_row["Team"]
            predicted_prob = predicted_row["avg_prob"]

            # Actual champion
            true_champion_row = test_df[test_df["Champion"] == 1]
            if not true_champion_row.empty:
                true_team = true_champion_row.iloc[0]["Team"]
                true_prob = true_champion_row.iloc[0]["avg_prob"]
            else:
                true_team = None
                true_prob = None

            correct = predicted_team == true_team
            correct_predictions += correct  # Increment correct prediction counter

            # Store result
            results.append({
                "Season": season,
                "Predicted Champion": predicted_team,
                "Predicted Prob": round(predicted_prob, 2),
                "Actual Champion": true_team,
                "Actual Prob": round(true_prob, 2) if true_prob is not None else None,
                "Correct": correct
            })

            if print_results:
                # Optional console output
                print(f"\n📅 Season: {season}")
                print(f"🏆 Predicted Champion: {predicted_team} (Prob: {predicted_prob:.2f}%)")
                print(f"👑 Actual Champion:    {true_team} (Prob: {true_prob:.2f}%)")
                print("✅ Correct prediction!" if correct else "❌ Wrong prediction!")

        # Calculate accuracy after all seasons have been processed
        total_seasons = len(seasons)
        accuracy = (correct_predictions / total_seasons) * 100

        print(f"\n🎯 Overall Prediction Accuracy for k={k}, threshold={threshold}: {accuracy:.2f}% ({correct_predictions} out of {total_seasons} seasons)")

        # Store the result of this grid search
        grid_search_results.append({
            "k": k,
            "threshold": threshold,
            "accuracy": accuracy,
            "correct_predictions": correct_predictions,
            "total_seasons": total_seasons,
            "results": results
        })

        # Save the results for each grid search parameter to a file
        if save:
            # Save the full grid search results to a pickle file
            with open("grid_search_results.pkl", "wb") as f:
                pickle.dump(grid_search_results, f)
            # Optionally save the results for this combination of parameters to a CSV file
            results_df = pd.DataFrame(results)
            results_df.to_csv(f"champions_predictions/champion_predictions_k{k}_threshold{threshold}.csv", index=False)
            print(f"📁 Results saved to 'champion_predictions_k{k}_threshold{threshold}.csv'")

    # Return the full grid search results for later use
    return grid_search_results


# Example of how to call this function:
k_values = list(range(10, 48))
# Define threshold_values from 0.05 to 1.0 (inclusive) with a step of 0.05
threshold_values = [round(i * 0.05 + 0.5, 2) for i in range(10)]  # Generates [0.5, 0.55, ..., 0.95]
# Perform grid search and save results
grid_search_results = perform_grid_search(seasons, teams, k_values, threshold_values, print_results=False, save=True)

# %%
champions_files = glob('champions_predictions/*47*')

if len(champions_files) > 0:
    for file in champions_files:
        results_df = pd.read_csv(file)
        
        # Calculate accuracy
        accuracy = results_df["Correct"].mean() * 100
        
        # Display accuracy for the current k value
        print(f"✅ Prediction Accuracy for K ({file}): {accuracy:.2f}% ({results_df['Correct'].sum()} out of {len(results_df)} seasons)")
else:
    print('No predictions were made')
# Out:
# ✅ Prediction Accuracy for K (champions_predictions/champion_predictions_47.csv): 35.56% (16 out of 45 seasons)

# %%
def load_current_year():
    current_year = get_bbref_teams_dataframe(first_year=2025,
                                             last_year=2025,
                                             find_champion=False,
                                             save=False)
    
    current_year_with_metrics = pd.DataFrame(current_year)
    return current_year_with_metrics

def predict_champions(teams, current_year):
    # Set the test set to the current year and train on all available historical data
    test_df = current_year.reset_index(drop=True)
    train_df = teams.reset_index(drop=True)

    # Separate features and labels for training
    x_train = train_df.drop(columns=["Champion", "Season", "Team"])
    y_train = train_df[["Champion"]]

    # Prepare features for testing (current year data)
    x_test = test_df.drop(columns=["Season", "Team"])
    
    for df in [x_train, x_test]:
        if "Unnamed: 0" in df.columns:
            print('Dropped Unnamed: 0')
            df.drop(columns=["Unnamed: 0"], inplace=True)

    # Make predictions using the trained model
    test_df["avg_prob"] = create_and_train_big_model(x_train, y_train, x_test, k=15)

    # Collect predicted teams and their probabilities
    predictions = test_df[["Team", "avg_prob"]].sort_values(by="avg_prob", ascending=False)


    predicted_row = predictions.iloc[0]
    predicted_team = predicted_row["Team"]
    predicted_prob = predicted_row["avg_prob"]
    print(f"\n🏆 Predicted Champion for 2025: {predicted_team} (Prob: {predicted_prob:.2f}%)")
    
    return predictions, predicted_team, predicted_prob

# %%
current_year_data = load_current_year()
# Out:
# 100%|██████████| 1/1 [00:07<00:00,  7
# 21         Toronto Raptors   0.705740
# 13         Houston Rockets   0.658892
# 20               Utah Jazz   0.513587
# 29           Brooklyn Nets   0.450159
# 27           Orlando Magic   0.448554
# 26      Washington Wizards   0.442098
# 22  Portland Trail Blazers   0.434923
# 24    New Orleans Pelicans   0.430614
# 28       Charlotte Hornets   0.425630

# %%
selector = SelectKBest(score_func=f_classif, k=15)
x_train, to_drop = drop_highly_correlated_features(x_train, threshold=0.8)
x_test = x_test.drop(columns=to_drop)
x_train_selected = selector.fit_transform(x_train, y_train)

# 1. Get a boolean mask of selected features
selected_mask = selector.get_support()  # True for selected, False otherwise

# 2. Get the actual column names selected
selected_features = x_train.columns[selected_mask]

# 3. See their F-scores (higher = more important)
feature_scores = selector.scores_  # same order as x_train.columns

# Optional: combine into a nice table
import pandas as pd

feature_importance_df = pd.DataFrame({
    "Feature": x_train.columns,
    "F_score": selector.scores_,
    "Selected": selected_mask
}).sort_values("F_score", ascending=False)

print(feature_importance_df)
# Out:
#        Feature     F_score  Selected
# 17           W  113.096446      True
# 2          FG%   84.745434      True
# 20        DRtg   66.092940      True
# 19        ORtg   60.544212      True
# 16         Age   50.608996      True
# 11         AST   40.513230      True
# 9          DRB   39.854847      True
# 0   Unnamed: 0   29.638001      True
# 15          PF   24.015640      True
# 18         SOS   20.394881      True
# 10         TRB   17.263275      True
# 13         BLK   17.094963      True
# 22        DRB%   13.947469      True
# 23   Attend./G   13.617696      True
# 5           2P   13.502674      True
# 14         TOV    3.635918     False
# 4          3P%    3.166478     False
# 12         STL    2.055463     False
# 6           FT    1.895908     False
# 3           3P    1.769427     False
# 8          ORB    1.535587     False
# 21        Pace    0.575167     False
# 1          FGA    0.532987     False
# 7          FT%    0.443108     False

# %%
x_test
# Out:
#     Unnamed: 0       FGA       FG%        3P       3P%        2P        FT  \
# 0            0  0.042745  0.069620  0.031250  0.021858  0.153584 -0.052941
# 1            1  0.014623  0.027426  0.289062  0.060109 -0.064846 -0.041176
# 2            2  0.004499  0.052743  0.039062  0.062842  0.068259  0.041176
# 3            3 -0.004499  0.027426  0.109375  0.019126 -0.010239  0.088235
# 4            4  0.040495 -0.018987  0.070312 -0.005464  0.000000  0.088235
# 5            5 -0.015748  0.052743 -0.078125  0.030055  0.085324  0.111765
# 6            6  0.008999  0.014768  0.140625  0.008197 -0.027304  0.000000
# 7            7  0.030371  0.006329  0.156250  0.038251 -0.013652 -0.082353
# 8            8  0.022497  0.006329  0.125000  0.000000 -0.010239 -0.088235
# 9            9 -0.031496  0.040084 -0.031250  0.043716  0.023891  0.111765
# 10          10  0.011249 -0.014768  0.007812 -0.032787 -0.006826  0.105882
# 11          11 -0.024747  0.031646 -0.015625  0.040984  0.013652  0.076471
# 12          12 -0.016873  0.025316 -0.023438  0.046448  0.023891  0.035294
# 13          13 -0.001125  0.046414 -0.085938  0.021858  0.102389 -0.111765
# 14          14  0.005624 -0.021097 -0.054688 -0.008197  0.003413  0.147059
# 15          15  0.023622 -0.031646 -0.007813 -0.038251 -0.010239  0.064706
